# %% [markdown]
# ### PYTHON PROJECT
# ### NAME:Danso T wum Kwadjo
# ### ID: 10947466
# ### DEPARTMENT:Computer Engineering

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
print(df)
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df=df.rename(columns={'fixed acidity':'fixed_acidity','citric acid':'citric_acid','volatile acidity':'volatile_acidity','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %%
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# ### Displaying the data.csv after renaming

# %%
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %% [markdown]
# ### Getting  information about data.csv

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1600 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1600 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free_sulfur_dioxide   1600 non-null   float64
#  7   total_sulfur_dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### Dropping NaN  values

# %%
df=df.dropna()
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
print('mode:',df.mode())
print('median:',df.median())
print('mean:',df.mean())
print('std:',df.std())
# Out:
# mode:         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.2               0.6          0.0             2.0
# 1        2            NaN               NaN          NaN             NaN
# 2        4            NaN               NaN          NaN             NaN
# 3        5            NaN               NaN          NaN             NaN
# 4        6            NaN               NaN          NaN             NaN
# ...    ...            ...               ...          ...             ...
# 1586  1597            NaN               NaN          NaN             NaN
# 1587  1598            NaN               NaN          NaN             NaN
# 1588  1599            NaN               NaN          NaN             NaN
# 1589  1600            NaN               NaN          NaN             NaN
# 1590  1601            NaN               NaN          NaN             NaN
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density   pH  \
# ...

# %% [markdown]
# ### Grabbing only the density column and displaying the mode, median, mean and std

# %%
print('mode:', df['density'].mode())
print('median:', df['density'].median())
print('mean:', df['density'].mean())
print('std:', df['density'].std())
# Out:
# mode: 0    0.9972
# Name: density, dtype: float64
# median: 0.99675
# mean: 0.9967456437500002
# std: 0.0018872613578228613

# %%
sns.histplot(df.density)
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
df.max()
# Out:
# ID                      1601.00000
# fixed_acidity             15.90000
# volatile_acidity           1.58000
# citric_acid                1.00000
# residual_sugar            15.50000
# chlorides                  0.61100
# free_sulfur_dioxide       72.00000
# total_sulfur_dioxide     289.00000
# density                    1.00369
# pH                         4.01000
# sulphates                  2.00000
# alcohol                   14.90000
# quality                    8.00000
# dtype: float64

# %%
sns.histplot(df.citric_acid)
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %%
print('fixed_acidity:',df['fixed_acidity'].max())
print('residual_sugar:',df['residual_sugar'].max())
print('citric_acid:',df['citric_acid'].max())
print('density:',df['density'].max())
print('quality:',df['quality'].max())
print('pH:',df['pH'].max())
# Out:
# fixed_acidity: 15.9
# residual_sugar: 15.5
# citric_acid: 1.0
# density: 1.00369
# quality: 8.0
# pH: 4.01

# %%
X=['15.9','15.5','1.0','8','4.01']
mylabels=['fixed_acidity','residual_sugar','citric_acid','quality','pH']
plt.pie(X, labels=mylabels)
plt.title('A PIE CHART THAT SHOWS PRODUCT WITH MAXIMUM VALUES')
plt.show()

# %%
X=['15.9','15.5','1.0','8','4.01']
mylabels=['fixed_acidity','residual_sugar','citric_acid','quality','pH']
plt.pie(X, labels=mylabels, startangle=0,explode=(0.1,0.1,0.12,0.1,0.1))
plt.title('A PIE CHART THAT SHOWS PRODUCT WITH MAXIMUM VALUES WITH EXPLODED VIEW')
plt.show()

# %%
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# ### Displaying the  maximum values of the various columns

# %%
print(df,df['quality'])
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df['quality']
# Out:
# 0       5.0
# 1       5.0
# 2       5.0
# 3       6.0
# 4       5.0
#        ...
# 1596    6.0
# 1597    6.0
# 1598    5.0
# 1599    6.0
# 1600    6.0
# Name: quality, Length: 1601, dtype: float64

# %%
sns.regplot(x='quality',y='pH',data=df)
plt.title('A Linear Regression Graph of pH against quality')
# Out:
# Text(0.5, 1.0, 'A Linear Regression Graph of pH against quality')

# %%
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %%
sns.barplot(x=df['quality'],y=df['pH'])
plt.title('A BAR GRAPH OF pH AGAINST QUALITY')
plt.show()

# %%
plt.scatter(x=df['fixed_acidity'],y=df['residual_sugar'])
plt.title('A scatter graph of fixed_acidity against residual_sugar')
plt.show()

# %%
print(df)
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
print('maximum quality:',df['quality'].max())
print('manimum quality:',df['quality'].min())
print('maximum pH:',df['pH'].max())
print('maximum pH:',df['pH'].min())
# Out:
# maximum quality: 8.0
# manimum quality: 3.0
# maximum pH: 4.01
# maximum pH: 2.74

# %%
mean=[4.01,2.74]
cov=[[4.01,8],[2.74,3.0]]

# %%
sns.kdeplot(df,x=df['pH'],fill=True, color='green')
# Out:
# <Axes: xlabel='pH', ylabel='Density'>

# %%
sns.regplot(x=df['alcohol'], y=df['pH'],data=df )
plt.title('A Linear Regression Graph of pH against alcohol')
# Out:
# Text(0.5, 1.0, 'A Linear Regression Graph of pH against alcohol')

# %%
corr_matrix= df.corr()
sns.heatmap(corr_matrix, annot=False)
plt.title('A heatmap of data.csv')
plt.show()

# %%
num=df['total_sulfur_dioxide']
sns.displot(num,color='green')
plt.title('A graph of total_sulfur_dioxide against count')
# Out:
# Text(0.5, 1.0, 'A graph of total_sulfur_dioxide against count')
